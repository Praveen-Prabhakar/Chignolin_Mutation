# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate
import cv2

# %%
Y2A = cv2.imread('Y2A.jpg')
Wild = cv2.imread('Wild.jpg')
Y1A = cv2.imread('Y1A.jpg')

# %%
columns = 3
rows = 4
fig = plt.figure(figsize =(40,15))
fig.subplots_adjust(hspace=0.1,wspace =0.05)
fig.add_subplot(1,3,1)
plt.imshow(cv2.cvtColor(Wild, cv2.COLOR_BGR2RGB))
plt.axis('off')
fig.add_subplot(1,3,2)
plt.imshow(cv2.cvtColor(Y1A, cv2.COLOR_BGR2RGB))
plt.axis('off')
fig.add_subplot(1,3,3)
plt.imshow(cv2.cvtColor(Y2A, cv2.COLOR_BGR2RGB))
plt.axis('off')
#fig.tight_layout()
plt.savefig('present_3.jpg',bbox_inches='tight',dpi =500)
plt.show()

# %%
plt.imshow(Y1A)
