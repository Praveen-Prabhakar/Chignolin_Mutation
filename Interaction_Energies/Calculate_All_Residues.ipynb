# %%
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

# %%
data_Wild_1 = np.loadtxt("Wild_1")
data_Wild_2 = np.loadtxt("Wild_2")
data_Wild_3 = np.loadtxt("Wild_3")
data_Wild_4 = np.loadtxt("Wild_4")
data_Wild_5 = np.loadtxt("Wild_5")
data_Wild_6 = np.loadtxt("Wild_6")
data_Wild_7 = np.loadtxt("Wild_7")
data_Wild_8 = np.loadtxt("Wild_8")
data_Wild_9 = np.loadtxt("Wild_9")
data_Wild_10 = np.loadtxt("Wild_10")
data_1 = np.loadtxt("Res_1")
data_2 = np.loadtxt("Res_2")
data_3 = np.loadtxt("Res_3")
data_4 = np.loadtxt("Res_4")
data_5 = np.loadtxt("Res_5")
data_6 = np.loadtxt("Res_6")
data_7 = np.loadtxt("Res_7")
data_7R = np.loadtxt("Res_7R")
data_8 = np.loadtxt("Res_8")
data_9 = np.loadtxt("Res_9")
data_10 = np.loadtxt("Res_10")

# %%
#residue 1 and rest of protein 
data_Wild_1[:,1] = data_Wild_1[:,1]/500
data_1[:,1] = data_1[:,1]/500
plt.plot(data_Wild_1[:,1],data_Wild_1[:,4],'b')
plt.plot(data_1[:,1],data_1[:,4],'r')
plt.legend(['Wild Chignolin','Y1A'],loc='lower right')
plt.xlabel('time (ns)')
plt.ylabel('Energy (kcal/mol)')
plt.title('Y1A')
plt.axhline(y=np.mean(data_Wild_1[:,4]),color='black')
plt.axhline(y=np.mean(data_1[:,4]),color='lime')
plt.savefig('Y1A.jpg',bbox_inches='tight',dpi=500)

# %%
#residue 2 and rest of protein 
data_Wild_2[:,1] = data_Wild_2[:,1]/500
data_2[:,1] = data_2[:,1]/500
plt.plot(data_Wild_2[:,1],data_Wild_2[:,4],'b')
plt.plot(data_2[:,1],data_2[:,4],'r')
plt.legend(['Wild Chignolin','Y2A'],loc='lower right')
plt.xlabel('time (ns)')
plt.ylabel('Energy (kcal/mol)')
plt.title('Y2A')
plt.axhline(y=np.mean(data_Wild_2[:,4]),color = 'black')
plt.axhline(y=np.mean(data_2[:,4]),color='lime')
plt.savefig('Y2A.jpg',bbox_inches='tight',dpi=500)

# %%
#residue 3 and rest of protein 
data_Wild_3[:,1] = data_Wild_3[:,1]/500
data_3[:,1] = data_3[:,1]/500
plt.plot(data_Wild_3[:,1],data_Wild_3[:,4],'b')
plt.plot(data_3[:,1],data_3[:,4],'r')
plt.legend(['Wild Chignolin','D3A'],loc='lower right')
plt.xlabel('time (ns)')
plt.title('D3A')
plt.ylabel('Energy (kcal/mol)')
plt.axhline(y=np.mean(data_Wild_3[:,4]),color='black')
plt.axhline(y=np.mean(data_3[:,4]),color='lime')
plt.savefig('D3A.jpg',bbox_inches='tight',dpi=500)

# %%
#residue 4 and rest of protein 
data_Wild_4[:,1] = data_Wild_4[:,1]/500
data_4[:,1] = data_4[:,1]/500
plt.plot(data_Wild_4[:,1],data_Wild_4[:,4],'b')
plt.plot(data_4[:,1],data_4[:,4],'r')
plt.legend(['Wild Chignolin','P4A'],loc='lower right')
plt.xlabel('time (ns)')
plt.title('P4A')
plt.ylabel('Energy (kcal/mol)')
plt.axhline(y=np.mean(data_Wild_4[:,4]),color='black')
plt.axhline(y=np.mean(data_4[:,4]),color='lime')
plt.savefig('P4A.jpg',bbox_inches='tight',dpi=500)

# %%
#residue 5 and rest of protein 
data_Wild_5[:,1] = data_Wild_5[:,1]/500
data_5[:,1] = data_5[:,1]/500
plt.plot(data_Wild_5[:,1],data_Wild_5[:,4],'b')
plt.plot(data_5[:,1],data_5[:,4],'r')
plt.legend(['Wild Chignolin','E5A'],loc='lower right')
plt.xlabel('time (ns)')
plt.ylim([-60,0])
plt.title('E5A')
plt.ylabel('Energy (kcal/mol)')
plt.axhline(y=np.mean(data_Wild_5[:,2]),color='black')
plt.axhline(y=np.mean(data_5[:,2]),color='lime')
plt.savefig('E5A.jpg',bbox_inches='tight',dpi=500)

# %%
#residue 6 and rest of protein 
data_Wild_6[:,1] = data_Wild_6[:,1]/500
data_6[:,1] = data_6[:,1]/500
plt.plot(data_Wild_6[:,1],data_Wild_6[:,4],'b')
plt.plot(data_6[:,1],data_6[:,4],'r')
plt.legend(['Wild Chignolin','T6A'],loc='lower right')
plt.xlabel('time (ns)')
plt.title('T6A')
plt.ylim([-75,-20])
plt.ylabel('Energy (kcal/mol)')
plt.axhline(y=np.mean(data_Wild_6[:,4]),color='black')
plt.axhline(y=np.mean(data_6[:,4]),color='lime')
plt.savefig('T6A.jpg',bbox_inches='tight',dpi=500)

# %%
#residue 7 and rest of protein 
data_Wild_7[:,1] = data_Wild_7[:,1]/500
data_7[:,1] = data_7[:,1]/500
plt.plot(data_Wild_7[:,1],data_Wild_7[:,4],'b')
plt.plot(data_7[:,1],data_7[:,4],'r')
plt.legend(['Wild Chignolin','G7D'],loc='lower right')
plt.xlabel('time (ns)')
plt.title('G7D')
plt.ylim([-70,15])
plt.ylabel('Energy (kcal/mol)')
plt.axhline(y=np.mean(data_Wild_7[:,4]),color='black')
plt.axhline(y=np.mean(data_7[:,4]),color='lime')
plt.savefig('G7D.jpg',bbox_inches='tight',dpi=500)

# %%
#residue 7 and rest of protein 
data_Wild_7 = np.loadtxt("Wild_7")
data_Wild_7[:,1] = data_Wild_7[:,1]/500
data_7R[:,1] = data_7R[:,1]/500
plt.plot(data_Wild_7[:,1],data_Wild_7[:,4],'b')
plt.plot(data_7R[:,1],data_7R[:,4],'r')
plt.legend(['Wild Chignolin','G7R'],loc='lower right')
plt.xlabel('time (ns)')
plt.title('G7R')
plt.ylabel('Energy (kcal/mol)')
plt.axhline(y=np.mean(data_Wild_7[:,4]),color='black')
plt.axhline(y=np.mean(data_7R[:,4]),color='lime')
plt.savefig('G7R.jpg',bbox_inches='tight',dpi=500)

# %%
#residue 8 and rest of protein 
data_Wild_8[:,1] = data_Wild_8[:,1]/500
data_8[:,1] = data_8[:,1]/500
plt.plot(data_Wild_8[:,1],data_Wild_8[:,4],'b')
plt.plot(data_8[:,1],data_8[:,4],'r')
plt.legend(['Wild Chignolin','T8A'],loc='lower right')
plt.xlabel('time (ns)')
plt.title('T8A')
plt.ylabel('Energy (kcal/mol)')
plt.axhline(y=np.mean(data_Wild_8[:,4]),color='black')
plt.axhline(y=np.mean(data_8[:,4]),color='lime')
plt.savefig('T8A.jpg',bbox_inches='tight',dpi=500)

# %%
#residue 9 and rest of protein 
data_Wild_9[:,1] = data_Wild_9[:,1]/500
data_9[:,1] = data_9[:,1]/500
plt.plot(data_Wild_9[:,1],data_Wild_9[:,4],'b')
plt.plot(data_9[:,1],data_9[:,4],'r')
plt.legend(['Wild Chignolin','W9A'],loc='lower right')
plt.xlabel('time (ns)')
plt.title('W9A')
plt.ylabel('Energy (kcal/mol)')
plt.axhline(y=np.mean(data_Wild_9[:,4]),color='black')
plt.axhline(y=np.mean(data_9[:,4]),color='lime')
plt.savefig('W9A.jpg',bbox_inches='tight',dpi=500)

# %%
#residue 9 and rest of protein 
data_Wild_10[:,1] = data_Wild_10[:,1]/500
data_10[:,1] = data_10[:,1]/500
plt.plot(data_Wild_10[:,1],data_Wild_10[:,4],'b')
plt.plot(data_10[:,1],data_10[:,4],'r')
plt.legend(['Wild Chignolin','Y10A'],loc='lower right')
plt.xlabel('time (ns)')
plt.title('Y10A')
plt.ylabel('Energy (kcal/mol)')
plt.axhline(y=np.mean(data_Wild_10[:,4]),color='black')
plt.axhline(y=np.mean(data_10[:,4]),color='lime')
plt.savefig('Y10A.jpg',bbox_inches='tight',dpi=500)
